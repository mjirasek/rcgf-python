# %%
import biot_savart as bs

# %%
# bs.write_target_volume("coil.txt", "coil", (30, 15, 15), (-5, -0.5, -2.5), 1, 1)
# generates a target volume from the coil stored at coil.txt
# uses a 30 x 15 x 15 bounding box, starting at (-5, -0.5, -2.5)
# uses 1 cm resolution

# bs.plot_coil("coil.txt")
# plots the coil stored at coil.txt

fields, positions = bs.read_target_volume("coil")
# reads the volume we created

# bs.plot_fields(fields, positions, which_plane='z', level=0, num_contours=50)
# plots the fields we just produced
# plotting along the plane x = 5, with 50 contours

# %%
# bs.calculate_field('coil.txt',1,0)

# %%
positions
# Out:
# array([[[[-5. , -0.5, -2.5],
#          [-5. , -0.5, -1.5],
#          [-5. , -0.5, -0.5],
#          ...,
#          [-5. , -0.5, 10.5],
#          [-5. , -0.5, 11.5],
#          [-5. , -0.5, 12.5]],
#
#         [[-5. ,  0.5, -2.5],
#          [-5. ,  0.5, -1.5],
#          [-5. ,  0.5, -0.5],
#          ...,
#          [-5. ,  0.5, 10.5],
#          [-5. ,  0.5, 11.5],
#          [-5. ,  0.5, 12.5]],
#
#         [[-5. ,  1.5, -2.5],
#          [-5. ,  1.5, -1.5],
#          [-5. ,  1.5, -0.5],
#          ...,
#          [-5. ,  1.5, 10.5],
#          [-5. ,  1.5, 11.5],
#          [-5. ,  1.5, 12.5]],
#
#         ...,
#
#         [[-5. , 12.5, -2.5],
#          [-5. , 12.5, -1.5],
#          [-5. , 12.5, -0.5],
#          ...,
#          [-5. , 12.5, 10.5],
#          [-5. , 12.5, 11.5],
#          [-5. , 12.5, 12.5]],
#
#         [[-5. , 13.5, -2.5],
#          [-5. , 13.5, -1.5],
#          [-5. , 13.5, -0.5],
#          ...,
#          [-5. , 13.5, 10.5],
#          [-5. , 13.5, 11.5],
#          [-5. , 13.5, 12.5]],
#
#         [[-5. , 14.5, -2.5],
#          [-5. , 14.5, -1.5],
#          [-5. , 14.5, -0.5],
#          ...,
#          [-5. , 14.5, 10.5],
#          [-5. , 14.5, 11.5],
#          [-5. , 14.5, 12.5]]],
#
#
#        [[[-4. , -0.5, -2.5],
#          [-4. , -0.5, -1.5],
#          [-4. , -0.5, -0.5],
#          ...,
#          [-4. , -0.5, 10.5],
#          [-4. , -0.5, 11.5],
#          [-4. , -0.5, 12.5]],
#
#         [[-4. ,  0.5, -2.5],
#          [-4. ,  0.5, -1.5],
#          [-4. ,  0.5, -0.5],
#          ...,
#          [-4. ,  0.5, 10.5],
#          [-4. ,  0.5, 11.5],
#          [-4. ,  0.5, 12.5]],
#
#         [[-4. ,  1.5, -2.5],
#          [-4. ,  1.5, -1.5],
#          [-4. ,  1.5, -0.5],
#          ...,
#          [-4. ,  1.5, 10.5],
#          [-4. ,  1.5, 11.5],
#          [-4. ,  1.5, 12.5]],
#
#         ...,
#
#         [[-4. , 12.5, -2.5],
#          [-4. , 12.5, -1.5],
#          [-4. , 12.5, -0.5],
#          ...,
#          [-4. , 12.5, 10.5],
#          [-4. , 12.5, 11.5],
#          [-4. , 12.5, 12.5]],
#
#         [[-4. , 13.5, -2.5],
#          [-4. , 13.5, -1.5],
#          [-4. , 13.5, -0.5],
#          ...,
#          [-4. , 13.5, 10.5],
#          [-4. , 13.5, 11.5],
#          [-4. , 13.5, 12.5]],
#
#         [[-4. , 14.5, -2.5],
#          [-4. , 14.5, -1.5],
#          [-4. , 14.5, -0.5],
#          ...,
#          [-4. , 14.5, 10.5],
#          [-4. , 14.5, 11.5],
#          [-4. , 14.5, 12.5]]],
#
#
#        [[[-3. , -0.5, -2.5],
#          [-3. , -0.5, -1.5],
#          [-3. , -0.5, -0.5],
#          ...,
#          [-3. , -0.5, 10.5],
#          [-3. , -0.5, 11.5],
#          [-3. , -0.5, 12.5]],
#
#         [[-3. ,  0.5, -2.5],
#          [-3. ,  0.5, -1.5],
#          [-3. ,  0.5, -0.5],
#          ...,
#          [-3. ,  0.5, 10.5],
#          [-3. ,  0.5, 11.5],
#          [-3. ,  0.5, 12.5]],
#
#         [[-3. ,  1.5, -2.5],
#          [-3. ,  1.5, -1.5],
#          [-3. ,  1.5, -0.5],
#          ...,
#          [-3. ,  1.5, 10.5],
#          [-3. ,  1.5, 11.5],
#          [-3. ,  1.5, 12.5]],
#
#         ...,
#
#         [[-3. , 12.5, -2.5],
#          [-3. , 12.5, -1.5],
#          [-3. , 12.5, -0.5],
#          ...,
#          [-3. , 12.5, 10.5],
#          [-3. , 12.5, 11.5],
#          [-3. , 12.5, 12.5]],
#
#         [[-3. , 13.5, -2.5],
#          [-3. , 13.5, -1.5],
#          [-3. , 13.5, -0.5],
#          ...,
#          [-3. , 13.5, 10.5],
#          [-3. , 13.5, 11.5],
#          [-3. , 13.5, 12.5]],
#
#         [[-3. , 14.5, -2.5],
#          [-3. , 14.5, -1.5],
#          [-3. , 14.5, -0.5],
#          ...,
#          [-3. , 14.5, 10.5],
#          [-3. , 14.5, 11.5],
#          [-3. , 14.5, 12.5]]],
#
#
#        ...,
#
#
#        [[[23. , -0.5, -2.5],
#          [23. , -0.5, -1.5],
#          [23. , -0.5, -0.5],
#          ...,
#          [23. , -0.5, 10.5],
#          [23. , -0.5, 11.5],
#          [23. , -0.5, 12.5]],
#
#         [[23. ,  0.5, -2.5],
#          [23. ,  0.5, -1.5],
#          [23. ,  0.5, -0.5],
#          ...,
#          [23. ,  0.5, 10.5],
#          [23. ,  0.5, 11.5],
#          [23. ,  0.5, 12.5]],
#
#         [[23. ,  1.5, -2.5],
#          [23. ,  1.5, -1.5],
#          [23. ,  1.5, -0.5],
#          ...,
#          [23. ,  1.5, 10.5],
#          [23. ,  1.5, 11.5],
#          [23. ,  1.5, 12.5]],
#
#         ...,
#
#         [[23. , 12.5, -2.5],
#          [23. , 12.5, -1.5],
#          [23. , 12.5, -0.5],
#          ...,
#          [23. , 12.5, 10.5],
#          [23. , 12.5, 11.5],
#          [23. , 12.5, 12.5]],
#
#         [[23. , 13.5, -2.5],
#          [23. , 13.5, -1.5],
#          [23. , 13.5, -0.5],
#          ...,
#          [23. , 13.5, 10.5],
#          [23. , 13.5, 11.5],
#          [23. , 13.5, 12.5]],
#
#         [[23. , 14.5, -2.5],
#          [23. , 14.5, -1.5],
#          [23. , 14.5, -0.5],
#          ...,
#          [23. , 14.5, 10.5],
#          [23. , 14.5, 11.5],
#          [23. , 14.5, 12.5]]],
#
#
#        [[[24. , -0.5, -2.5],
#          [24. , -0.5, -1.5],
#          [24. , -0.5, -0.5],
#          ...,
#          [24. , -0.5, 10.5],
#          [24. , -0.5, 11.5],
#          [24. , -0.5, 12.5]],
#
#         [[24. ,  0.5, -2.5],
#          [24. ,  0.5, -1.5],
#          [24. ,  0.5, -0.5],
#          ...,
#          [24. ,  0.5, 10.5],
#          [24. ,  0.5, 11.5],
#          [24. ,  0.5, 12.5]],
#
#         [[24. ,  1.5, -2.5],
#          [24. ,  1.5, -1.5],
#          [24. ,  1.5, -0.5],
#          ...,
#          [24. ,  1.5, 10.5],
#          [24. ,  1.5, 11.5],
#          [24. ,  1.5, 12.5]],
#
#         ...,
#
#         [[24. , 12.5, -2.5],
#          [24. , 12.5, -1.5],
#          [24. , 12.5, -0.5],
#          ...,
#          [24. , 12.5, 10.5],
#          [24. , 12.5, 11.5],
#          [24. , 12.5, 12.5]],
#
#         [[24. , 13.5, -2.5],
#          [24. , 13.5, -1.5],
#          [24. , 13.5, -0.5],
#          ...,
#          [24. , 13.5, 10.5],
#          [24. , 13.5, 11.5],
#          [24. , 13.5, 12.5]],
#
#         [[24. , 14.5, -2.5],
#          [24. , 14.5, -1.5],
#          [24. , 14.5, -0.5],
#          ...,
#          [24. , 14.5, 10.5],
#          [24. , 14.5, 11.5],
#          [24. , 14.5, 12.5]]],
#
#
#        [[[25. , -0.5, -2.5],
#          [25. , -0.5, -1.5],
#          [25. , -0.5, -0.5],
#          ...,
#          [25. , -0.5, 10.5],
#          [25. , -0.5, 11.5],
#          [25. , -0.5, 12.5]],
#
#         [[25. ,  0.5, -2.5],
#          [25. ,  0.5, -1.5],
#          [25. ,  0.5, -0.5],
#          ...,
#          [25. ,  0.5, 10.5],
#          [25. ,  0.5, 11.5],
#          [25. ,  0.5, 12.5]],
#
#         [[25. ,  1.5, -2.5],
#          [25. ,  1.5, -1.5],
#          [25. ,  1.5, -0.5],
#          ...,
#          [25. ,  1.5, 10.5],
#          [25. ,  1.5, 11.5],
#          [25. ,  1.5, 12.5]],
#
#         ...,
#
#         [[25. , 12.5, -2.5],
#          [25. , 12.5, -1.5],
#          [25. , 12.5, -0.5],
#          ...,
#          [25. , 12.5, 10.5],
#          [25. , 12.5, 11.5],
#          [25. , 12.5, 12.5]],
#
#         [[25. , 13.5, -2.5],
#          [25. , 13.5, -1.5],
#          [25. , 13.5, -0.5],
#          ...,
#          [25. , 13.5, 10.5],
#          [25. , 13.5, 11.5],
#          [25. , 13.5, 12.5]],
#
#         [[25. , 14.5, -2.5],
#          [25. , 14.5, -1.5],
#          [25. , 14.5, -0.5],
#          ...,
#          [25. , 14.5, 10.5],
#          [25. , 14.5, 11.5],
#          [25. , 14.5, 12.5]]]])
